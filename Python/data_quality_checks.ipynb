# %%
import pandas as pd

# %%
#importing the files
calendar = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\calendar.csv")
products = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\products.csv")
customers = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\customer.csv")
orders = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\orders.csv")

# %%
calendar.shape
# Out:
# (1096, 4)

# %%
products.shape
# Out:
# (50, 3)

# %%
customers.shape
# Out:
# (1000, 3)

# %%
orders.shape
# Out:
# (20000, 7)

# %%
orders.head()
# Out:
#    order_id  order_date  customer_id  product_id  quantity  unit_price region
# 0         1  2024-04-15          985          13         4      237.75   East
# 1         2  2022-06-18          732          47         4      375.70  North
# 2         3  2022-08-05          180           5         1       72.33   East
# 3         4  2023-01-13          358          24         5      171.10  South
# 4         5  2022-04-29          740          38         1       67.86  South

# %%
#checking for null/missing vales

# %%
orders.isnull().sum()
# Out:
# order_id       0
# order_date     0
# customer_id    0
# product_id     0
# quantity       0
# unit_price     0
# region         0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# customer_type    0
# city             0
# dtype: int64

# %%
calendar.isnull().sum()
# Out:
# date       0
# year       0
# month      0
# quarter    0
# dtype: int64

# %%
# To check Referance or connectivity between each tables

# %%
orders["customer_id"].isin(customers["customer_id"]).value_counts()
# Out:
# customer_id
# True    20000
# Name: count, dtype: int64

# %%
orders["product_id"].isin(products["product_id"]).value_counts()
# Out:
# product_id
# True    20000
# Name: count, dtype: int64

# %%
orders["order_date"].isin(calendar["date"]).value_counts()
# Out:
# order_date
# True    20000
# Name: count, dtype: int64
