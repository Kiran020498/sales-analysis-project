# %%
import pandas as pd

# %%
calendar = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\calendar.csv")
products = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\products.csv")
customers = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\customer.csv")
orders = pd.read_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Raw\orders.csv")

# %%
orders.dtypes
# Out:
# order_id         int64
# order_date      object
# customer_id      int64
# product_id       int64
# quantity         int64
# unit_price     float64
# region          object
# dtype: object

# %%
#order_date to datetime
orders["order_date"] = pd.to_datetime(orders["order_date"])

# %%
#Creating a revenue column
orders["revenue"] = orders["quantity"] * orders["unit_price"]

# %%
#Standardize region values
orders["region"] = orders["region"].str.title()

# %%
orders.isnull().sum()
# Out:
# order_id       0
# order_date     0
# customer_id    0
# product_id     0
# quantity       0
# unit_price     0
# region         0
# revenue        0
# dtype: int64

# %%
orders.head()
# Out:
#    order_id order_date  customer_id  product_id  quantity  unit_price region  \
# 0         1 2024-04-15          985          13         4      237.75   East
# 1         2 2022-06-18          732          47         4      375.70  North
# 2         3 2022-08-05          180           5         1       72.33   East
# 3         4 2023-01-13          358          24         5      171.10  South
# 4         5 2022-04-29          740          38         1       67.86  South
#
#    revenue
# 0   951.00
# 1  1502.80
# 2    72.33
# 3   855.50
# 4    67.86

# %%
orders.dtypes
# Out:
# order_id                int64
# order_date     datetime64[ns]
# customer_id             int64
# product_id              int64
# quantity                int64
# unit_price            float64
# region                 object
# revenue               float64
# dtype: object

# %%
#Saving Cleaned Data
orders.to_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Cleaned\orders_cleaned.csv", index=False)
products.to_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Cleaned\products_cleaned.csv", index=False)
customers.to_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Cleaned\customers_cleaned.csv", index=False)
calendar.to_csv(r"C:\Users\Kiran Kumar\sales-analysis-project\Data\Data-Cleaned\calendar_cleaned.csv", index=False)
